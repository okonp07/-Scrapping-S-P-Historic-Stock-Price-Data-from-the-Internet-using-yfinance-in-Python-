# %% [markdown]
# # S&P 500 Historical Prices with `yfinance`
#
# This notebook is a lightweight walkthrough for the maintained downloader module in this repository.

# %% [markdown]
# ## Important caveat
#
# This workflow uses the **current** S&P 500 constituents table from Wikipedia and then downloads prices for the date window you choose. It does **not** rebuild historical S&P 500 membership for past years, so it should not be used as a true historical-index-membership dataset.

# %% [markdown]
# ## Setup
#
# Install the project dependencies before running the notebook:
#
# ```bash
# python3 -m pip install -r requirements.txt
# ```
#
# If you are running inside Jupyter, `pip install -e .` also works.

# %%
from pathlib import Path

from sp500_historical_prices.downloader import (
    download_adjusted_close,
    fetch_sp500_constituents,
)

START = "2017-01-01"
END = "2023-01-01"

# %%
constituents = fetch_sp500_constituents()
constituents[["Wikipedia Symbol", "Yahoo Symbol", "Security"]].head()

# %%
prices, dropped_symbols = download_adjusted_close(
    tickers=constituents["Yahoo Symbol"].tolist(),
    start=START,
    end=END,
    show_progress=False,
)

print(f"Downloaded {len(prices.columns)} symbols from {START} to {END}.")
print("Dropped symbols with no data:", dropped_symbols)
prices.head()

# %%
output_dir = Path("outputs")
output_dir.mkdir(exist_ok=True)

clean_constituents = constituents[
    ~constituents["Yahoo Symbol"].isin(dropped_symbols)
].reset_index(drop=True)

prices_path = output_dir / "sp500_adjusted_close.csv"
constituents_path = output_dir / "sp500_constituents.csv"

prices.to_csv(prices_path, index=True)
clean_constituents.to_csv(constituents_path, index=False)

print(f"Saved prices to {prices_path.resolve()}")
print(f"Saved constituents to {constituents_path.resolve()}")

# %% [markdown]
# ## Reproducible CLI run
#
# For a scriptable version of the same workflow, run:
#
# ```bash
# python3 scripts/download_sp500_prices.py --start 2017-01-01 --end 2023-01-01
# ```
